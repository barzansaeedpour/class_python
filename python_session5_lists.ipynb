# %% [markdown]
# <div dir="rtl">
#
# # جلسه ۵ – لیست‌ها
#
# در این جلسه با **لیست‌ها (Lists)** در پایتون آشنا می‌شویم.
# لیست‌ها ساختاری هستند که می‌توانند چندین مقدار را در یک متغیر نگه‌داری کنند.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## ایجاد و ویرایش لیست
#
# یک لیست را می‌توان با استفاده از `[]` ایجاد کرد:
#
# </div>

# %%
# ایجاد یک لیست ساده
fruits = ["سیب", "موز", "گیلاس"]
print(fruits)

# %% [markdown]
# <div dir="rtl">
#
# ## متدهای مهم لیست
#
# - `append()` : اضافه کردن عنصر در انتهای لیست
# - `insert()` : اضافه کردن عنصر در مکان مشخص
# - `remove()` : حذف اولین occurrence یک عنصر
# - `pop()` : حذف عنصر بر اساس ایندکس
# - `sort()` : مرتب‌سازی لیست
#
# </div>

# %%
fruits = ["سیب", "موز", "گیلاس"]
fruits.append("انگور")
print("بعد از append:", fruits)

fruits.insert(1, "پرتقال")
print("بعد از insert:", fruits)

fruits.remove("موز")
print("بعد از remove:", fruits)

last_item = fruits.pop()
print("بعد از pop:", fruits, "  حذف شده:", last_item)

numbers = [5, 2, 9, 1, 7]
numbers.sort()
print("مرتب شده:", numbers)

# %% [markdown]
# <div dir="rtl">
#
# ## پیمایش لیست با حلقه
#
# با استفاده از حلقه `for` می‌توان روی عناصر لیست پیمایش کرد:
#
# </div>

# %%
fruits = ["سیب", "پرتقال", "موز"]
for fruit in fruits:
    print("میوه:", fruit)

# %% [markdown]
# <div dir="rtl">
#
# ## تمرین: سایر متدهای لیست
#
# پنج متد مهم دیگر لیست را سرچ کنید و مثال های آن را در زیر اضافه کنید
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## تمرینات ساده
#
# 1. لیستی از ۵ عدد بسازید و آن را مرتب کنید.
# 2. لیستی از اسامی ایجاد کنید و یکی از آن‌ها را با استفاده از ایندکس تغییر دهید.
# 3. برنامه‌ای بنویسید که بررسی کند آیا یک عنصر در لیست وجود دارد یا خیر.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## تمرین: برنامه مدیریت لیست خرید
#
# یک برنامه بنویسید که:
#
# 1. یک لیست خرید خالی ایجاد کند.
# 2. با استفاده از `append` چند آیتم به لیست اضافه کند.
# 3. یک آیتم خاص را حذف کند.
# 4. تمام آیتم‌ها را با حلقه چاپ کند.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## تمرینات: ترکیب لیست و حلقه‌ها
#
# 1. لیستی از اعداد بسازید و مجموع تمام آن‌ها را با حلقه محاسبه کنید.
# 2. برنامه‌ای بنویسید که تعداد تکرار یک عنصر خاص در لیست را پیدا کند.
# 3. لیستی از کلمات بسازید و همه آن‌ها را به صورت جداگانه چاپ کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## تمرینات پیشرفته
#
# 1. برنامه‌ای بنویسید که بزرگ‌ترین و کوچک‌ترین عدد موجود در یک لیست را پیدا کند.
# 2. برنامه‌ای بنویسید که لیستی از اعداد گرفته و فقط اعداد زوج را در یک لیست جدید ذخیره کند.
# 3. برنامه‌ای بنویسید که دو لیست را با هم ترکیب کند.
# 4. برنامه‌ای بنویسید که لیستی از رشته‌ها را گرفته و طول هر رشته را در لیستی جدید ذخیره کند.
#
# </div>
